# %%
#Reseau de neurones pour identification de locuteur
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

feature_train = np.genfromtxt('Features_Train.dat', dtype=None)
feature_test = np.genfromtxt('Features_Test.dat', dtype=None)
label_train = np.genfromtxt('Labels_Train.dat', dtype=None)
label_test = np.genfromtxt('Labels_Test.dat', dtype=None)
#Les ex sont en lignes (12ou85x16) (train_ou_test)

#Définition de l'Architecture:
#on utilise 2 couches et un noeud en sortie
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(5,input_shape=(16,), activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1))

model.summary()

model.compile(loss='mse',optimizer='adam')
model.fit(feature_train,label_train, batch_size=1,epochs=100)
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_85 (Dense)             (None, 5)                 85
# _________________________________________________________________
# dense_86 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_87 (Dense)             (None, 1)                 6
# ...
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Train on 12 samples
# Epoch 1/100
# 12/12 [==============================] - 0s 37ms/sample - loss: 24.2156
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/sample - loss: 23.7021
# Epoch 3/100
# 12/12 [==============================] - 0s 2ms/sample - loss: 23.1373
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/sample - loss: 22.4741
# Epoch 5/100
# ...

# %%
predictions = model.predict(feature_test)

# %%
predictions
# Out:
# array([[4.7985387],
#        [5.004305 ],
#        [4.8989043],
#        [5.1003   ],
#        [4.919002 ],
#        [4.8339596],
#        [5.5002713],
#        [5.5329547],
#        [5.0365863],
#        [5.410343 ],
#        [5.302809 ],
#        [5.127738 ],
#        [5.0130224],
#        [5.061003 ],
#        [5.0902195],
#        [6.2092643],
#        [6.0760303],
#        [5.8785887],
#        [4.4703236],
#        [4.5029283],
#        [5.2578006],
#        [5.2647724],
#        [5.1441545],
#        [5.127789 ],
#        [4.694875 ],
#        [4.7015557],
#        [4.4725165],
#        [4.81268  ],
#        [4.8738947],
#        [4.5991883],
#        [5.12475  ],
#        [5.241187 ],
#        [5.3295517],
#        [5.2760754],
#        [5.5245104],
#        [5.4638987],
#        [5.6155915],
#        [5.58006  ],
#        [5.380557 ],
#        [5.433984 ],
#        [4.4753857],
#        [4.4675355],
#        [4.4707985],
#        [4.627715 ],
#        [4.642474 ],
# ...
